# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]: 


from ast import arg
import time
import argparse
import numpy as np
import torch
from models.GCN import GCN
from models.GCN_Encoder import GCN_Encoder
from torch_geometric.datasets import Planetoid, WebKB, WikipediaNetwork,Reddit,Reddit2,Flickr,Yelp,PPI
from torch_geometric.utils import to_dense_adj,dense_to_sparse

# from ogb.nodeproppred import PygNodePropPredDataset
# from torch_geometric.loader import DataLoader
from help_funcs import prune_unrelated_edge,prune_unrelated_edge_isolated,select_target_nodes
import help_funcs
import scipy.sparse as sp

# Training settings
parser = argparse.ArgumentParser()
parser.add_argument('--debug', action='store_true',
        default=True, help='debug mode')
parser.add_argument('--no-cuda', action='store_true', default=False,
                    help='Disables CUDA training.')
parser.add_argument('--seed', type=int, default=10, help='Random seed.')
parser.add_argument('--model', type=str, default='GCN', help='model',
                    choices=['GCN','GAT','GraphSage','GIN'])
parser.add_argument('--dataset', type=str, default='Cora', 
                    help='Dataset',
                    choices=['Cora','Citeseer','Pubmed','PPI','Flickr','ogbn-arxiv','Reddit','Reddit2','Yelp'])
parser.add_argument('--train_lr', type=float, default=0.01,
                    help='Initial learning rate.')
parser.add_argument('--weight_decay', type=float, default=5e-4,
                    help='Weight decay (L2 loss on parameters).')
parser.add_argument('--hidden', type=int, default=32,
                    help='Number of hidden units.')
parser.add_argument('--thrd', type=float, default=0.5)
parser.add_argument('--target_class', type=int, default=0)
parser.add_argument('--dropout', type=float, default=0.5,
                    help='Dropout rate (1 - keep probability).')
parser.add_argument('--epochs', type=int,  default=200, help='Number of epochs to train benign and backdoor model.')
parser.add_argument('--trojan_epochs', type=int,  default=200, help='Number of epochs to train trigger generator.')
parser.add_argument('--inner', type=int,  default=1, help='Number of inner')
# backdoor setting
parser.add_argument('--lr', type=float, default=0.01,
                    help='Initial learning rate.')
parser.add_argument('--trigger_size', type=int, default=3,
                    help='tirgger_size')
parser.add_argument('--vs_ratio', type=float, default=0.005,
                    help="ratio of poisoning nodes relative to the full graph")
# defense setting
parser.add_argument('--defense_mode', type=str, default="guard",
                    choices=['prune', 'isolate', 'none', 'guard', 'median'],
                    help="Mode of defense")
parser.add_argument('--prune_thr', type=float, default=0.15,
                    help="Threshold of prunning edges")
parser.add_argument('--target_loss_weight', type=float, default=1,
                    help="Weight of optimize outter trigger generator")
parser.add_argument('--homo_loss_weight', type=float, default=3,
                    help="Weight of optimize similarity loss")
parser.add_argument('--homo_boost_thrd', type=float, default=0.5,
                    help="Threshold of increase similarity")
# attack setting
parser.add_argument('--dis_weight', type=float, default=1,
                    help="Weight of cluster distance")
parser.add_argument('--attack_method', type=str, default='Basic',
                    choices=['Rand_Gene','Rand_Samp','Basic','None','TDGIA','AGIA'],
                    help='Method to select idx_attach for training trojan model (none means randomly select)')
parser.add_argument('--trigger_prob', type=float, default=0.5,
                    help="The probability to generate the trigger's edges in random method")
parser.add_argument('--selection_method', type=str, default='none',
                    choices=['loss','conf','cluster','none','cluster_degree'],
                    help='Method to select idx_attach for training trojan model (none means randomly select)')
parser.add_argument('--test_model', type=str, default='GCN',
                    choices=['GCN','GAT','GraphSage','GIN'],
                    help='Model used to attack')
parser.add_argument('--evaluate_mode', type=str, default='overall',
                    choices=['overall','1by1'],
                    help='Model used to attack')
# GPU setting
parser.add_argument('--device_id', type=int, default=0,
                    help="Threshold of prunning edges")
# args = parser.parse_args()
args = parser.parse_known_args()[0]
args.cuda =  not args.no_cuda and torch.cuda.is_available()
device = torch.device(('cuda:{}' if torch.cuda.is_available() else 'cpu').format(args.device_id))
# device2 = torch.device(('cuda:{}' if torch.cuda.is_available() else 'cpu').format(args.device_id+1))

# np.random.seed(args.seed)
torch.manual_seed(args.seed)
torch.cuda.manual_seed(args.seed)

np.random.seed(args.seed)
torch.manual_seed(args.seed)
torch.cuda.manual_seed(args.seed)
print(args)
def setup_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     np.random.seed(seed)
    #  random.seed(seed)
     torch.backends.cudnn.deterministic = True
# 设置随机数种子
setup_seed(args.seed)
#%%
from torch_geometric.utils import to_undirected
import torch_geometric.transforms as T
transform = T.Compose([T.NormalizeFeatures()])

np.random.seed(11) # fix the random seed is important
if(args.dataset == 'Cora' or args.dataset == 'Citeseer' or args.dataset == 'Pubmed'):
    dataset = Planetoid(root='./data/', \
                        name=args.dataset,\
                        transform=transform)
elif(args.dataset == 'Flickr'):
    dataset = Flickr(root='./data/Flickr/', \
                    transform=transform)
elif(args.dataset == 'PPI'):
    dataset = PPI(root='./data/PPI/', 
                split='train', transform=None)
elif(args.dataset == 'Reddit2'):
    dataset = Reddit2(root='./data/Reddit2/', \
                    transform=transform)
elif(args.dataset == 'ogbn-arxiv'):
    # Download and process data at './dataset/ogbg_molhiv/'
    dataset = PygNodePropPredDataset(name = 'ogbn-arxiv', root='./data/')
    split_idx = dataset.get_idx_split() 
elif(args.dataset == 'Yelp'):
    # Download and process data at './dataset/ogbg_molhiv/'
    dataset = Yelp(root='./data/Yelp/')
    # idx_train, idx_val, idx_test = split_idx["train"], split_idx["valid"], split_idx["test"]


data = dataset[0].to(device)

if(args.dataset == 'ogbn-arxiv'):
    nNode = data.x.shape[0]
    setattr(data,'train_mask',torch.zeros(nNode, dtype=torch.bool).to(device))
    # dataset[0].train_mask = torch.zeros(nEdge, dtype=torch.bool).to(device)
    data.val_mask = torch.zeros(nNode, dtype=torch.bool).to(device)
    data.test_mask = torch.zeros(nNode, dtype=torch.bool).to(device)
    data.y = data.y.squeeze(1)
# we build our own train test split 
from utils import get_split
data, idx_train, idx_val, idx_clean_test, idx_atk = get_split(args,data,device)

print(data)

#%%
from torch_geometric.utils import to_undirected
from utils import subgraph
data.edge_index = to_undirected(data.edge_index)
train_edge_index,_, edge_mask = subgraph(torch.bitwise_not(data.test_mask),data.edge_index,relabel_nodes=False)
mask_edge_index = data.edge_index[:,torch.bitwise_not(edge_mask)]

# In[3]:

# In[6]: 
import os
from models.backdoor import model_construct
benign_modelpath = './modelpath/{}_{}_benign.pth'.format(args.model, args.dataset)
if(os.path.exists(benign_modelpath)):
    # load existing benign model
    benign_model = torch.load(benign_modelpath)
    benign_model = benign_model.to(device)
    # edge_weights = torch.ones([data.edge_index.shape[1]],device=device,dtype=torch.float)
    print("Loading benign {} model Finished!".format(args.model))
else:
    benign_model = model_construct(args,args.test_model,data,device).to(device) 
    t_total = time.time()
    print("Length of training set: {}".format(len(idx_train)))
    benign_model.fit(data.x, train_edge_index, None, data.y, idx_train, idx_val,train_iters=args.epochs,verbose=False)
    print("Training benign model Finished!")
    print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
    # Save trained model
    # torch.save(benign_model, benign_modelpath)
    # print("Benign model saved at {}".format(benign_modelpath))

# In[7]:

benign_ca = benign_model.test(data.x, data.edge_index, None, data.y,idx_clean_test)
print("Benign CA: {:.4f}".format(benign_ca))
benign_model = benign_model.cpu()

# In[9]:

# from sklearn_extra import cluster
# from models.backdoor import obtain_attach_nodes,Backdoor, obtain_attach_nodes_by_cluster_degree, obtain_attach_nodes_by_cluster_gpu,obtain_attach_nodes_by_influential,obtain_attach_nodes_by_cluster,cluster_distance_selection,cluster_degree_selection

# from kmeans_pytorch import kmeans, kmeans_predict
# from models.backdoor import defend_baseline_construct

from sklearn_extra import cluster
from models.backdoor import Backdoor, defend_baseline_construct
from heuristic_selection import obtain_attach_nodes, obtain_attach_nodes_by_cluster_degree, obtain_attach_nodes_by_cluster_gpu,obtain_attach_nodes_by_influential,obtain_attach_nodes_by_cluster,cluster_distance_selection,cluster_degree_selection

from kmeans_pytorch import kmeans, kmeans_predict

# filter out the unlabeled nodes except from training nodes and testing nodes, nonzero() is to get index, flatten is to get 1-d tensor
unlabeled_idx = (torch.bitwise_not(data.test_mask)&torch.bitwise_not(data.train_mask)).nonzero().flatten()
size = int((len(data.test_mask)-data.test_mask.sum())*args.vs_ratio)
# here is randomly select poison nodes from unlabeled nodes
if(args.selection_method == 'none'):
    idx_attach = obtain_attach_nodes(args,unlabeled_idx,size)
elif(args.selection_method == 'loss' or args.selection_method == 'conf'):
    idx_attach = obtain_attach_nodes_by_influential(args,benign_model,unlabeled_idx.cpu().tolist(),data.x,train_edge_index,None,data.y,device,size,selected_way=args.selection_method)
    idx_attach = torch.LongTensor(idx_attach).to(device)
elif(args.selection_method == 'cluster'):
    idx_attach = cluster_distance_selection(args,data,idx_train,idx_val,idx_clean_test,unlabeled_idx,train_edge_index,size,device)
    idx_attach = torch.LongTensor(idx_attach).to(device)
elif(args.selection_method == 'cluster_degree'):
    idx_attach = cluster_degree_selection(args,data,idx_train,idx_val,idx_clean_test,unlabeled_idx,train_edge_index,size,device)
    idx_attach = torch.LongTensor(idx_attach).to(device)

# In[10]:
# train trigger generator 
model = Backdoor(args,device)
if(args.attack_method == 'Basic'):
    model.fit(data.x, train_edge_index, None, data.y, idx_train,idx_attach, unlabeled_idx)
    poison_x, poison_edge_index, poison_edge_weights, poison_labels = model.get_poisoned()
elif(args.attack_method == 'Rand_Gene' or args.attack_method == 'Rand_Samp'):
    model.fit_rand(data.x, train_edge_index, None, data.y, idx_train,idx_attach, unlabeled_idx)
    poison_x, poison_edge_index, poison_edge_weights, poison_labels = model.get_poisoned_rand()
elif(args.attack_method == 'None'):
    train_edge_weights = torch.ones([train_edge_index.shape[1]],device=device,dtype=torch.float)
    poison_x, poison_edge_index, poison_edge_weights, poison_labels = data.x.clone(), train_edge_index.clone(), train_edge_weights, data.y.clone()
elif(args.attack_method == 'TDGIA' or args.attack_method == 'AGIA'):
    train_edge_weights = torch.ones([train_edge_index.shape[1]],device=device,dtype=torch.float)
    poison_x, poison_edge_index, poison_edge_weights, poison_labels = data.x.clone(), train_edge_index.clone(), train_edge_weights, data.y.clone()
    # build surrogate model
    surrogate_model = model_construct(args,args.model,data,device).to(device) 
    t_total = time.time()
    # print("Length of training set: {}".format(len(idx_train)))
    print("Training Surrogate Model...")
    surrogate_model.fit(data.x, train_edge_index, None, data.y, idx_train, idx_val,train_iters=args.epochs,verbose=True)
    print("Training Completed...")
# In[12]:
if(args.defense_mode == 'prune'):
    poison_edge_index,poison_edge_weights = prune_unrelated_edge(args,poison_edge_index,poison_edge_weights,poison_x,device)
    bkd_tn_nodes = torch.cat([idx_train,idx_attach]).to(device)
elif(args.defense_mode == 'isolate'):
    poison_edge_index,poison_edge_weights,rel_nodes = prune_unrelated_edge_isolated(args,poison_edge_index,poison_edge_weights,poison_x,device)
    bkd_tn_nodes = torch.cat([idx_train,idx_attach]).tolist()
    bkd_tn_nodes = torch.LongTensor(list(set(bkd_tn_nodes) - set(rel_nodes))).to(device)
else:
    bkd_tn_nodes = torch.cat([idx_train,idx_attach]).to(device)

print("precent of left attach nodes: {:.3f}"\
    .format(len(set(bkd_tn_nodes.tolist()) & set(idx_attach.tolist()))/len(idx_attach)))
#%%
# test_model = model_construct(args,args.test_model,data,device).to(device) 
test_model = defend_baseline_construct(args,args.defense_mode,args.test_model,data,device).to(device) 
test_model.fit(poison_x, poison_edge_index, poison_edge_weights, poison_labels, bkd_tn_nodes, idx_val,train_iters=args.epochs,verbose=False)

output = test_model(poison_x,poison_edge_index,poison_edge_weights)
train_attach_rate = (output.argmax(dim=1)[idx_attach]==args.target_class).float().mean()
print("target class rate on Vs: {:.4f}".format(train_attach_rate)) 

train_attach_rate = (poison_labels[idx_attach]==args.target_class).float().mean()
print("target class rate on Vs: {:.4f}".format(train_attach_rate)) 
#%%
from torch_sparse import SparseTensor
from baseline_atk import baseline_attack_parser, attack_baseline_construct
induct_edge_index = torch.cat([poison_edge_index,mask_edge_index],dim=1)
induct_edge_weights = torch.cat([poison_edge_weights,torch.ones([mask_edge_index.shape[1]],dtype=torch.float,device=device)])
clean_acc = test_model.test(poison_x,induct_edge_index,induct_edge_weights,data.y,idx_clean_test)
# test_model = test_model.cpu()

print("accuracy on clean test nodes: {:.4f}".format(clean_acc))

# poison_x, poison_edge_index, poison_edge_weights, poison_labels = poison_x.to(device2), poison_edge_index.to(device2), poison_edge_weights.to(device2), poison_labels.to(device2)
# model.trojan = model.trojan.cpu()
if(args.evaluate_mode == '1by1'):
    from torch_geometric.utils  import k_hop_subgraph
    overall_induct_edge_index, overall_induct_edge_weights = induct_edge_index.clone(),induct_edge_weights.clone()
    asr = 0
    for i, idx in enumerate(idx_atk):
        idx=int(idx)
        sub_induct_nodeset, sub_induct_edge_index, sub_mapping, sub_edge_mask  = k_hop_subgraph(node_idx = [idx], num_hops = 2, edge_index = overall_induct_edge_index, relabel_nodes=True) # sub_mapping means the index of [idx] in sub)nodeset
        ori_node_idx = sub_induct_nodeset[sub_mapping]
        relabeled_node_idx = sub_mapping
        sub_induct_edge_weights = torch.ones([sub_induct_edge_index.shape[1]]).to(device)
        # inject trigger on attack test nodes (idx_atk)'''
        if(args.attack_method == 'Basic'):
            induct_x, induct_edge_index,induct_edge_weights = model.inject_trigger(relabeled_node_idx,poison_x[sub_induct_nodeset],sub_induct_edge_index,sub_induct_edge_weights,device)
        elif(args.attack_method == 'Rand_Gene' or args.attack_method == 'Rand_Samp'):
            induct_x, induct_edge_index,induct_edge_weights = model.inject_trigger_rand(relabeled_node_idx,poison_x[sub_induct_nodeset],sub_induct_edge_index,sub_induct_edge_weights,data.y)
        elif(args.attack_method == 'None'):
            induct_x, induct_edge_index,induct_edge_weights = poison_x[sub_induct_nodeset],sub_induct_edge_index,sub_induct_edge_weights
        elif(args.attack_method == 'TDGIA'):
            induct_x, induct_edge_index,induct_edge_weights = poison_x[sub_induct_nodeset],sub_induct_edge_index,sub_induct_edge_weights
            atk_param = baseline_attack_parser(args,device)
            atk_param['n_inject_max'] = 3
            atk_param['n_edge_max'] = 1
            attacker = attack_baseline_construct(args,atk_param)
            sp_induct_adj = SparseTensor(row=induct_edge_index[0], col=induct_edge_index[1], value=induct_edge_weights)

            # induct_adj = to_dense_adj(induct_edge_index,edge_attr=induct_edge_weights)[0]
            # print(induct_adj.to_sparse())
            # sp_induct_adj = induct_adj.to_sparse()
            # print(sp_induct_adj.has_value())
            induct_adj, x_attack = attacker.attack(model=surrogate_model,
                                                    adj=sp_induct_adj,
                                                    features=induct_x,
                                                    target_idx=torch.tensor([relabeled_node_idx]),
                                                    labels=None)
            induct_x = torch.cat([induct_x,x_attack],dim=0)
            induct_edge_index,induct_edge_weights = dense_to_sparse(induct_adj.to_dense())
        induct_x, induct_edge_index,induct_edge_weights = induct_x.clone().detach(), induct_edge_index.clone().detach(),induct_edge_weights.clone().detach()
        # # do pruning in test datas'''
        if(args.defense_mode == 'prune' or args.defense_mode == 'isolate'):
            induct_edge_index,induct_edge_weights = prune_unrelated_edge(args,induct_edge_index,induct_edge_weights,induct_x,device)
        # attack evaluation
        
        # test_model = test_model.to(device)
        output = test_model(induct_x,induct_edge_index,induct_edge_weights)
        train_attach_rate = (output.argmax(dim=1)[relabeled_node_idx]==args.target_class).float().mean()
        print("Node {}: {}".format(i, idx))
        print("ASR: {:.4f}".format(train_attach_rate))
        asr += train_attach_rate
        # ca = test_model.test(induct_x,induct_edge_index,induct_edge_weights,data.y,idx_clean_test)
        # print("CA: {:.4f}".format(ca))
    asr = asr/(idx_atk.shape[0])
    print("Overall ASR: {:.4f}".format(asr))
elif(args.evaluate_mode == 'overall'):
    # %% inject trigger on attack test nodes (idx_atk)'''
    if(args.attack_method == 'Basic'):
        induct_x, induct_edge_index,induct_edge_weights = model.inject_trigger(idx_atk,poison_x,induct_edge_index,induct_edge_weights,device)
    elif(args.attack_method == 'Rand_Gene' or args.attack_method == 'Rand_Samp'):
        induct_x, induct_edge_index,induct_edge_weights = model.inject_trigger_rand(idx_atk,poison_x,induct_edge_index,induct_edge_weights,data.y)
    elif(args.attack_method == 'None'):
        induct_x, induct_edge_index,induct_edge_weights = poison_x,induct_edge_index,induct_edge_weights
    elif(args.attack_method == 'TDGIA' or args.attack_method == 'AGIA'):
        induct_x, induct_edge_index,induct_edge_weights = poison_x,data.edge_index,induct_edge_weights
        induct_edge_weights = torch.ones([data.edge_index.shape[1]],device=device,dtype=torch.float)
        atk_param = baseline_attack_parser(args,device)
        atk_param['n_inject_max'] = idx_atk.shape[0] * 3
        atk_param['n_edge_max'] = 1
        attacker = attack_baseline_construct(args,atk_param)
        sp_induct_adj = SparseTensor(row=induct_edge_index[0], col=induct_edge_index[1], value=induct_edge_weights)
        print(induct_edge_weights.shape)
        print(induct_x.shape)
        # induct_adj = to_dense_adj(induct_edge_index,edge_attr=induct_edge_weights)[0]
        # print(induct_adj.to_sparse())
        # sp_induct_adj = induct_adj.to_sparse()
        # print(sp_induct_adj.has_value())
        induct_adj, x_attack = attacker.attack(model=surrogate_model,
                                                adj=sp_induct_adj,
                                                features=induct_x,
                                                target_idx=idx_atk,
                                                labels=None)
        induct_x = torch.cat([induct_x,x_attack],dim=0)
        induct_edge_index,induct_edge_weights = dense_to_sparse(induct_adj.to_dense())
    induct_x, induct_edge_index,induct_edge_weights = induct_x.clone().detach(), induct_edge_index.clone().detach(),induct_edge_weights.clone().detach()
    # do pruning in test datas'''
    if(args.defense_mode == 'prune' or args.defense_mode == 'isolate'):
        induct_edge_index,induct_edge_weights = prune_unrelated_edge(args,induct_edge_index,induct_edge_weights,induct_x,device)
    # attack evaluation

    # test_model = test_model.to(device)
    output = test_model(induct_x,induct_edge_index,induct_edge_weights)
    if(args.attack_method == 'TDGIA' or args.attack_method == 'AGIA'):
        train_attach_rate = (output.argmax(dim=1)[idx_atk]!=data.y[idx_atk]).float().mean()
    else:
        train_attach_rate = (output.argmax(dim=1)[idx_atk]==args.target_class).float().mean()
    print("ASR: {:.4f}".format(train_attach_rate))
    ca = test_model.test(induct_x,induct_edge_index,induct_edge_weights,data.y,idx_clean_test)
    print("CA: {:.4f}".format(ca))
# Out:
# Namespace(attack_method='Basic', cuda=True, dataset='Cora', debug=True, defense_mode='guard', device_id=0, dis_weight=1, dropout=0.5, epochs=200, evaluate_mode='overall', hidden=32, homo_boost_thrd=0.5, homo_loss_weight=3, inner=1, lr=0.01, model='GCN', no_cuda=False, prune_thr=0.15, seed=10, selection_method='none', target_class=0, target_loss_weight=1, test_model='GCN', thrd=0.5, train_lr=0.01, trigger_prob=0.5, trigger_size=3, trojan_epochs=200, vs_ratio=0.005, weight_decay=0.0005)
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708])
# Length of training set: 541
# Training benign model Finished!
# Total time elapsed: 1.8465s
# Benign CA: 0.8370
# Epoch 0, loss_inner: 1.94621, loss_target: 1.93708, homo loss: 0.50406
# acc_train_clean: 0.1460, ASR_train_attach: 0.0000, ASR_train_outter: 0.0019
# Epoch 10, loss_inner: 1.75595, loss_target: 1.00523, homo loss: 0.36427
# acc_train_clean: 0.2828, ASR_train_attach: 1.0000, ASR_train_outter: 0.9981
# Epoch 20, loss_inner: 1.68480, loss_target: 1.08348, homo loss: 0.37712
# acc_train_clean: 0.2921, ASR_train_attach: 1.0000, ASR_train_outter: 1.0000
# Epoch 30, loss_inner: 1.56850, loss_target: 0.89228, homo loss: 0.28023
# acc_train_clean: 0.3974, ASR_train_attach: 1.0000, ASR_train_outter: 1.0000
# Epoch 40, loss_inner: 1.42236, loss_target: 0.77243, homo loss: 0.25131
# acc_train_clean: 0.5065, ASR_train_attach: 1.0000, ASR_train_outter: 1.0000
# Epoch 50, loss_inner: 1.24221, loss_target: 0.64290, homo loss: 0.23589
# acc_train_clean: 0.6174, ASR_train_attach: 1.0000, ASR_train_outter: 0.9943
# Epoch 60, loss_inner: 1.05557, loss_target: 0.60444, homo loss: 0.23547
# acc_train_clean: 0.7449, ASR_train_attach: 1.0000, ASR_train_outter: 0.9962
# Epoch 70, loss_inner: 0.88058, loss_target: 0.58801, homo loss: 0.18585
# acc_train_clean: 0.8521, ASR_train_attach: 0.7000, ASR_train_outter: 0.9368
# Epoch 80, loss_inner: 0.72955, loss_target: 0.44535, homo loss: 0.13390
# acc_train_clean: 0.9131, ASR_train_attach: 1.0000, ASR_train_outter: 0.9540
# Epoch 90, loss_inner: 0.63176, loss_target: 0.59797, homo loss: 0.15392
# acc_train_clean: 0.9261, ASR_train_attach: 0.9000, ASR_train_outter: 0.9483
# Epoch 100, loss_inner: 0.54117, loss_target: 0.35812, homo loss: 0.07659
# acc_train_clean: 0.9353, ASR_train_attach: 1.0000, ASR_train_outter: 0.9981
# Epoch 110, loss_inner: 0.48925, loss_target: 0.47501, homo loss: 0.05418
# acc_train_clean: 0.9427, ASR_train_attach: 0.7000, ASR_train_outter: 0.8180
# Epoch 120, loss_inner: 0.43882, loss_target: 0.29989, homo loss: 0.03611
# acc_train_clean: 0.9538, ASR_train_attach: 1.0000, ASR_train_outter: 0.9943
# Epoch 130, loss_inner: 0.40372, loss_target: 0.36375, homo loss: 0.03848
# acc_train_clean: 0.9593, ASR_train_attach: 1.0000, ASR_train_outter: 1.0000
# Epoch 140, loss_inner: 0.38077, loss_target: 0.33438, homo loss: 0.20008
# acc_train_clean: 0.9593, ASR_train_attach: 1.0000, ASR_train_outter: 0.9923
# Epoch 150, loss_inner: 0.36044, loss_target: 0.24612, homo loss: 0.04925
# acc_train_clean: 0.9630, ASR_train_attach: 0.8000, ASR_train_outter: 0.9828
# Epoch 160, loss_inner: 0.34920, loss_target: 0.23963, homo loss: 0.00035
# acc_train_clean: 0.9649, ASR_train_attach: 0.5000, ASR_train_outter: 0.9559
# Epoch 170, loss_inner: 0.32426, loss_target: 0.23776, homo loss: 0.00632
# acc_train_clean: 0.9649, ASR_train_attach: 0.8000, ASR_train_outter: 0.9828
# Epoch 180, loss_inner: 0.30992, loss_target: 0.20184, homo loss: 0.00077
# acc_train_clean: 0.9686, ASR_train_attach: 0.8000, ASR_train_outter: 1.0000
# Epoch 190, loss_inner: 0.30726, loss_target: 0.33705, homo loss: 0.06091
# acc_train_clean: 0.9686, ASR_train_attach: 1.0000, ASR_train_outter: 1.0000
# precent of left attach nodes: 1.000
# target class rate on Vs: 1.0000
# target class rate on Vs: 1.0000
# accuracy on clean test nodes: 0.7148
# ASR: 0.9889
# CA: 0.7111

# %%
import torch.nn.functional as F
from torch_geometric.utils import to_dense_adj
poison_adj_dense = to_dense_adj(poison_edge_index)
def edge_sim_analysis(edge_index, features):
    sims = []
    for (u,v) in edge_index:
        sims.append(float(F.cosine_similarity(features[u].unsqueeze(0),features[v].unsqueeze(0))))
    sims = np.array(sims)
    # print(f"mean: {sims.mean()}, <0.1: {sum(sims<0.1)}/{sims.shape[0]}")
    return sims

bkd_nids = list(range(data.x.shape[0],poison_x.shape[0]))
for nid in idx_attach:
    # polished_dr_test = copy.deepcopy(bkd_dr_test)
    # polished_adj_nodes = polished_dr_test.data['mat_adj'].to_dense()[nid].nonzero()
    polished_adj_nodes = poison_adj_dense[0][nid].nonzero()
    # bkd_nids = list(range(poison_x.shape[0],induct_x.shape[0]))
    for v in polished_adj_nodes:
        v = int(v)
        if(v in bkd_nids):
            u = nid
            print(nid,v)
            print(F.cosine_similarity(poison_x[u].unsqueeze(0),poison_x[v].unsqueeze(0)))
# Out:
# tensor(1032, device='cuda:0') 2708
# tensor([0.4862], device='cuda:0')
# tensor(1201, device='cuda:0') 2711
# tensor([0.5345], device='cuda:0')
# tensor(760, device='cuda:0') 2714
# tensor([0.5334], device='cuda:0')
# tensor(2567, device='cuda:0') 2717
# tensor([0.5273], device='cuda:0')
# tensor(1147, device='cuda:0') 2720
# tensor([0.5202], device='cuda:0')
# tensor(2063, device='cuda:0') 2723
# tensor([0.5417], device='cuda:0')
# tensor(2574, device='cuda:0') 2726
# tensor([0.5074], device='cuda:0')
# tensor(1535, device='cuda:0') 2729
# tensor([0.5272], device='cuda:0')
# tensor(843, device='cuda:0') 2732
# tensor([0.5263], device='cuda:0')
# tensor(801, device='cuda:0') 2735
# tensor([0.5114], device='cuda:0')

# %%
import torch.nn.functional as F
from torch_geometric.utils import to_dense_adj
induct_adj_dense = to_dense_adj(induct_edge_index)
def edge_sim_analysis(edge_index, features):
    sims = []
    for (u,v) in edge_index:
        sims.append(float(F.cosine_similarity(features[u].unsqueeze(0),features[v].unsqueeze(0))))
    sims = np.array(sims)
    # print(f"mean: {sims.mean()}, <0.1: {sum(sims<0.1)}/{sims.shape[0]}")
    return sims

bkd_nids = induct_x.shape[0] - poison_x.shape[0]
for nid in idx_atk:
    # polished_dr_test = copy.deepcopy(bkd_dr_test)
    # polished_adj_nodes = polished_dr_test.data['mat_adj'].to_dense()[nid].nonzero()
    polished_adj_nodes = induct_adj_dense[0][nid].nonzero()
    bkd_nids = list(range(poison_x.shape[0],induct_x.shape[0]))
    for v in polished_adj_nodes:
        v = int(v)
        if(v in bkd_nids):
            u = nid
            print(nid,v)
            print(F.cosine_similarity(induct_x[u].unsqueeze(0),induct_x[v].unsqueeze(0)))
# Out:
# tensor(1370, device='cuda:0') 2738
# tensor([0.4264], device='cuda:0')
# tensor(1376, device='cuda:0') 2741
# tensor([0.4098], device='cuda:0')
# tensor(1378, device='cuda:0') 2744
# tensor([0.2614], device='cuda:0')
# tensor(1392, device='cuda:0') 2747
# tensor([0.3986], device='cuda:0')
# tensor(1393, device='cuda:0') 2750
# tensor([0.1695], device='cuda:0')
# tensor(1400, device='cuda:0') 2753
# tensor([0.4181], device='cuda:0')
# tensor(1416, device='cuda:0') 2756
# tensor([0.3980], device='cuda:0')
# tensor(1422, device='cuda:0') 2759
# tensor([0.3949], device='cuda:0')
# tensor(1423, device='cuda:0') 2762
# tensor([0.3337], device='cuda:0')
# tensor(1425, device='cuda:0') 2765
# tensor([0.3992], device='cuda:0')
# tensor(1429, device='cuda:0') 2768
# tensor([0.3847], device='cuda:0')
# tensor(1434, device='cuda:0') 2771
# tensor([0.3863], device='cuda:0')
# tensor(1436, device='cuda:0') 2774
# tensor([0.3059], device='cuda:0')
# tensor(1437, device='cuda:0') 2777
# tensor([0.3060], device='cuda:0')
# tensor(1441, device='cuda:0') 2780
# tensor([0.4978], device='cuda:0')
# tensor(1442, device='cuda:0') 2783
# tensor([0.3687], device='cuda:0')
# tensor(1444, device='cuda:0') 2786
# tensor([0.2471], device='cuda:0')
# tensor(1448, device='cuda:0') 2789
# tensor([0.3170], device='cuda:0')
# tensor(1450, device='cuda:0') 2792
# tensor([0.3610], device='cuda:0')
# tensor(1452, device='cuda:0') 2795
# tensor([0.3576], device='cuda:0')
# tensor(1457, device='cuda:0') 2798
# tensor([0.2751], device='cuda:0')
# tensor(1476, device='cuda:0') 2801
# tensor([0.3242], device='cuda:0')
# tensor(1486, device='cuda:0') 2804
# tensor([0.1814], device='cuda:0')
# tensor(1487, device='cuda:0') 2807
# tensor([0.4200], device='cuda:0')
# tensor(1493, device='cuda:0') 2810
# tensor([0.3596], device='cuda:0')
# tensor(1499, device='cuda:0') 2813
# tensor([0.4230], device='cuda:0')
# tensor(1501, device='cuda:0') 2816
# tensor([0.2543], device='cuda:0')
# tensor(1506, device='cuda:0') 2819
# tensor([0.4493], device='cuda:0')
# tensor(1507, device='cuda:0') 2822
# tensor([0.3560], device='cuda:0')
# tensor(1523, device='cuda:0') 2825
# tensor([0.3776], device='cuda:0')
# tensor(1541, device='cuda:0') 2828
# tensor([0.4068], device='cuda:0')
# tensor(1546, device='cuda:0') 2831
# tensor([0.4052], device='cuda:0')
# tensor(1554, device='cuda:0') 2834
# tensor([0.1527], device='cuda:0')
# tensor(1561, device='cuda:0') 2837
# tensor([0.4058], device='cuda:0')
# tensor(1565, device='cuda:0') 2840
# tensor([0.2830], device='cuda:0')
# tensor(1567, device='cuda:0') 2843
# tensor([0.4754], device='cuda:0')
# tensor(1568, device='cuda:0') 2846
# tensor([0.3692], device='cuda:0')
# tensor(1583, device='cuda:0') 2849
# tensor([0.3811], device='cuda:0')
# tensor(1589, device='cuda:0') 2852
# tensor([0.3160], device='cuda:0')
# tensor(1591, device='cuda:0') 2855
# tensor([0.3123], device='cuda:0')
# tensor(1597, device='cuda:0') 2858
# tensor([0.4150], device='cuda:0')
# tensor(1600, device='cuda:0') 2861
# tensor([0.2856], device='cuda:0')
# tensor(1602, device='cuda:0') 2864
# tensor([0.4549], device='cuda:0')
# tensor(1605, device='cuda:0') 2867
# tensor([0.4761], device='cuda:0')
# tensor(1611, device='cuda:0') 2870
# tensor([0.2488], device='cuda:0')
# tensor(1628, device='cuda:0') 2873
# tensor([0.4359], device='cuda:0')
# tensor(1629, device='cuda:0') 2876
# tensor([0.3995], device='cuda:0')
# tensor(1632, device='cuda:0') 2879
# tensor([0.2902], device='cuda:0')
# tensor(1637, device='cuda:0') 2882
# tensor([0.4837], device='cuda:0')
# tensor(1644, device='cuda:0') 2885
# tensor([0.3958], device='cuda:0')
# tensor(1645, device='cuda:0') 2888
# tensor([0.2964], device='cuda:0')
# tensor(1653, device='cuda:0') 2891
# tensor([0.2145], device='cuda:0')
# tensor(1661, device='cuda:0') 2894
# tensor([0.3322], device='cuda:0')
# tensor(1668, device='cuda:0') 2897
# tensor([0.5218], device='cuda:0')
# tensor(1675, device='cuda:0') 2900
# tensor([0.3806], device='cuda:0')
# tensor(1679, device='cuda:0') 2903
# tensor([0.2343], device='cuda:0')
# tensor(1684, device='cuda:0') 2906
# tensor([0.2381], device='cuda:0')
# tensor(1688, device='cuda:0') 2909
# tensor([0.3514], device='cuda:0')
# tensor(1695, device='cuda:0') 2912
# tensor([0.3966], device='cuda:0')
# tensor(1705, device='cuda:0') 2915
# tensor([0.4682], device='cuda:0')
# tensor(1707, device='cuda:0') 2918
# tensor([0.3439], device='cuda:0')
# tensor(1726, device='cuda:0') 2921
# tensor([0.3972], device='cuda:0')
# tensor(1727, device='cuda:0') 2924
# tensor([0.4192], device='cuda:0')
# tensor(1734, device='cuda:0') 2927
# tensor([0.1276], device='cuda:0')
# tensor(1749, device='cuda:0') 2930
# tensor([0.4030], device='cuda:0')
# tensor(1752, device='cuda:0') 2933
# tensor([0.4952], device='cuda:0')
# tensor(1753, device='cuda:0') 2936
# tensor([0.4880], device='cuda:0')
# tensor(1760, device='cuda:0') 2939
# tensor([0.2207], device='cuda:0')
# tensor(1764, device='cuda:0') 2942
# tensor([0.2518], device='cuda:0')
# tensor(1768, device='cuda:0') 2945
# tensor([0.2772], device='cuda:0')
# tensor(1771, device='cuda:0') 2948
# tensor([0.3549], device='cuda:0')
# tensor(1777, device='cuda:0') 2951
# tensor([0.4142], device='cuda:0')
# tensor(1779, device='cuda:0') 2954
# tensor([0.4144], device='cuda:0')
# tensor(1781, device='cuda:0') 2957
# tensor([0.2917], device='cuda:0')
# tensor(1783, device='cuda:0') 2960
# tensor([0.2729], device='cuda:0')
# tensor(1786, device='cuda:0') 2963
# tensor([0.2848], device='cuda:0')
# tensor(1794, device='cuda:0') 2966
# tensor([0.1542], device='cuda:0')
# tensor(1803, device='cuda:0') 2969
# tensor([0.4078], device='cuda:0')
# tensor(1807, device='cuda:0') 2972
# tensor([0.3562], device='cuda:0')
# tensor(1809, device='cuda:0') 2975
# tensor([0.3497], device='cuda:0')
# tensor(1810, device='cuda:0') 2978
# tensor([0.3650], device='cuda:0')
# tensor(1817, device='cuda:0') 2981
# tensor([0.3206], device='cuda:0')
# tensor(1822, device='cuda:0') 2984
# tensor([0.2958], device='cuda:0')
# tensor(1825, device='cuda:0') 2987
# tensor([0.2229], device='cuda:0')
# tensor(1829, device='cuda:0') 2990
# tensor([0.3171], device='cuda:0')
# tensor(1836, device='cuda:0') 2993
# tensor([0.2578], device='cuda:0')
# tensor(1838, device='cuda:0') 2996
# tensor([0.2665], device='cuda:0')
# tensor(1841, device='cuda:0') 2999
# tensor([0.3694], device='cuda:0')
# tensor(1845, device='cuda:0') 3002
# tensor([0.2785], device='cuda:0')
# tensor(1852, device='cuda:0') 3005
# tensor([0.4308], device='cuda:0')
# tensor(1853, device='cuda:0') 3008
# tensor([0.4373], device='cuda:0')
# tensor(1858, device='cuda:0') 3011
# tensor([0.2264], device='cuda:0')
# tensor(1862, device='cuda:0') 3014
# tensor([0.3954], device='cuda:0')
# tensor(1866, device='cuda:0') 3017
# tensor([0.4534], device='cuda:0')
# tensor(1870, device='cuda:0') 3020
# tensor([0.2514], device='cuda:0')
# tensor(1872, device='cuda:0') 3023
# tensor([0.2153], device='cuda:0')
# tensor(1878, device='cuda:0') 3026
# tensor([0.4343], device='cuda:0')
# tensor(1879, device='cuda:0') 3029
# tensor([0.3411], device='cuda:0')
# tensor(1881, device='cuda:0') 3032
# tensor([0.3768], device='cuda:0')
# tensor(1891, device='cuda:0') 3035
# tensor([0.3268], device='cuda:0')
# tensor(1899, device='cuda:0') 3038
# tensor([0.2139], device='cuda:0')
# tensor(1901, device='cuda:0') 3041
# tensor([0.2699], device='cuda:0')
# tensor(1904, device='cuda:0') 3044
# tensor([0.4126], device='cuda:0')
# tensor(1906, device='cuda:0') 3047
# tensor([0.4526], device='cuda:0')
# tensor(1909, device='cuda:0') 3050
# tensor([0.4707], device='cuda:0')
# tensor(1911, device='cuda:0') 3053
# tensor([0.2931], device='cuda:0')
# tensor(1913, device='cuda:0') 3056
# tensor([0.2993], device='cuda:0')
# tensor(1916, device='cuda:0') 3059
# tensor([0.4392], device='cuda:0')
# tensor(1918, device='cuda:0') 3062
# tensor([0.4662], device='cuda:0')
# tensor(1920, device='cuda:0') 3065
# tensor([0.3247], device='cuda:0')
# tensor(1925, device='cuda:0') 3068
# tensor([0.2897], device='cuda:0')
# tensor(1931, device='cuda:0') 3071
# tensor([0.2433], device='cuda:0')
# tensor(1932, device='cuda:0') 3074
# tensor([0.2265], device='cuda:0')
# tensor(1936, device='cuda:0') 3077
# tensor([0.2497], device='cuda:0')
# tensor(1938, device='cuda:0') 3080
# tensor([0.2670], device='cuda:0')
# tensor(1942, device='cuda:0') 3083
# tensor([0.3190], device='cuda:0')
# tensor(1947, device='cuda:0') 3086
# tensor([0.3031], device='cuda:0')
# tensor(1959, device='cuda:0') 3089
# tensor([0.2095], device='cuda:0')
# tensor(1961, device='cuda:0') 3092
# tensor([0.3525], device='cuda:0')
# tensor(1962, device='cuda:0') 3095
# tensor([0.4408], device='cuda:0')
# tensor(1969, device='cuda:0') 3098
# tensor([0.2956], device='cuda:0')
# tensor(1972, device='cuda:0') 3101
# tensor([0.3661], device='cuda:0')
# tensor(1977, device='cuda:0') 3104
# tensor([0.4338], device='cuda:0')
# tensor(1983, device='cuda:0') 3107
# tensor([0.2663], device='cuda:0')
# tensor(1996, device='cuda:0') 3110
# tensor([0.4610], device='cuda:0')
# tensor(2004, device='cuda:0') 3113
# tensor([0.4298], device='cuda:0')
# tensor(2006, device='cuda:0') 3116
# tensor([0.4601], device='cuda:0')
# tensor(2010, device='cuda:0') 3119
# tensor([0.2671], device='cuda:0')
# tensor(2011, device='cuda:0') 3122
# tensor([0.3481], device='cuda:0')
# tensor(2014, device='cuda:0') 3125
# tensor([0.2601], device='cuda:0')
# tensor(2015, device='cuda:0') 3128
# tensor([0.3857], device='cuda:0')
# tensor(2019, device='cuda:0') 3131
# tensor([0.3302], device='cuda:0')
# tensor(2038, device='cuda:0') 3134
# tensor([0.3681], device='cuda:0')
# tensor(2043, device='cuda:0') 3137
# tensor([0.5017], device='cuda:0')
# tensor(2045, device='cuda:0') 3140
# tensor([0.3756], device='cuda:0')
# tensor(2051, device='cuda:0') 3143
# tensor([0.2905], device='cuda:0')
# tensor(2054, device='cuda:0') 3146
# tensor([0.3997], device='cuda:0')
# tensor(2055, device='cuda:0') 3149
# tensor([0.3488], device='cuda:0')
# tensor(2058, device='cuda:0') 3152
# tensor([0.2257], device='cuda:0')
# tensor(2059, device='cuda:0') 3155
# tensor([0.3097], device='cuda:0')
# tensor(2071, device='cuda:0') 3158
# tensor([0.4707], device='cuda:0')
# tensor(2072, device='cuda:0') 3161
# tensor([0.3968], device='cuda:0')
# tensor(2075, device='cuda:0') 3164
# tensor([0.3987], device='cuda:0')
# tensor(2082, device='cuda:0') 3167
# tensor([0.5001], device='cuda:0')
# tensor(2087, device='cuda:0') 3170
# tensor([0.2874], device='cuda:0')
# tensor(2096, device='cuda:0') 3173
# tensor([0.4204], device='cuda:0')
# tensor(2105, device='cuda:0') 3176
# tensor([0.4014], device='cuda:0')
# tensor(2107, device='cuda:0') 3179
# tensor([0.3186], device='cuda:0')
# tensor(2113, device='cuda:0') 3182
# tensor([0.3706], device='cuda:0')
# tensor(2120, device='cuda:0') 3185
# tensor([0.4672], device='cuda:0')
# tensor(2122, device='cuda:0') 3188
# tensor([0.2920], device='cuda:0')
# tensor(2130, device='cuda:0') 3191
# tensor([0.2669], device='cuda:0')
# tensor(2131, device='cuda:0') 3194
# tensor([0.3567], device='cuda:0')
# tensor(2139, device='cuda:0') 3197
# tensor([0.3775], device='cuda:0')
# tensor(2141, device='cuda:0') 3200
# tensor([0.3630], device='cuda:0')
# tensor(2153, device='cuda:0') 3203
# tensor([0.3733], device='cuda:0')
# tensor(2156, device='cuda:0') 3206
# tensor([0.4129], device='cuda:0')
# tensor(2157, device='cuda:0') 3209
# tensor([0.2361], device='cuda:0')
# tensor(2158, device='cuda:0') 3212
# tensor([0.1662], device='cuda:0')
# tensor(2160, device='cuda:0') 3215
# tensor([0.2644], device='cuda:0')
# tensor(2164, device='cuda:0') 3218
# tensor([0.3539], device='cuda:0')
# tensor(2165, device='cuda:0') 3221
# tensor([0.3095], device='cuda:0')
# tensor(2166, device='cuda:0') 3224
# tensor([0.2759], device='cuda:0')
# tensor(2172, device='cuda:0') 3227
# tensor([0.3944], device='cuda:0')
# tensor(2177, device='cuda:0') 3230
# tensor([0.6904], device='cuda:0')
# tensor(2181, device='cuda:0') 3233
# tensor([0.3678], device='cuda:0')
# tensor(2189, device='cuda:0') 3236
# tensor([0.3475], device='cuda:0')
# tensor(2195, device='cuda:0') 3239
# tensor([0.3704], device='cuda:0')
# tensor(2198, device='cuda:0') 3242
# tensor([0.3160], device='cuda:0')
# tensor(2212, device='cuda:0') 3245
# tensor([0.3756], device='cuda:0')
# tensor(2215, device='cuda:0') 3248
# tensor([0.5200], device='cuda:0')
# tensor(2218, device='cuda:0') 3251
# tensor([0.4534], device='cuda:0')
# tensor(2224, device='cuda:0') 3254
# tensor([0.2441], device='cuda:0')
# tensor(2228, device='cuda:0') 3257
# tensor([0.2526], device='cuda:0')
# tensor(2229, device='cuda:0') 3260
# tensor([0.3436], device='cuda:0')
# tensor(2231, device='cuda:0') 3263
# tensor([0.1904], device='cuda:0')
# tensor(2232, device='cuda:0') 3266
# tensor([0.4498], device='cuda:0')
# tensor(2235, device='cuda:0') 3269
# tensor([0.2857], device='cuda:0')
# tensor(2249, device='cuda:0') 3272
# tensor([0.2504], device='cuda:0')
# tensor(2264, device='cuda:0') 3275
# tensor([0.2799], device='cuda:0')
# tensor(2274, device='cuda:0') 3278
# tensor([0.4960], device='cuda:0')
# tensor(2279, device='cuda:0') 3281
# tensor([0.2773], device='cuda:0')
# tensor(2288, device='cuda:0') 3284
# tensor([0.3135], device='cuda:0')
# tensor(2293, device='cuda:0') 3287
# tensor([0.3241], device='cuda:0')
# tensor(2297, device='cuda:0') 3290
# tensor([0.1712], device='cuda:0')
# tensor(2299, device='cuda:0') 3293
# tensor([0.2074], device='cuda:0')
# tensor(2302, device='cuda:0') 3296
# tensor([0.4037], device='cuda:0')
# tensor(2310, device='cuda:0') 3299
# tensor([0.3497], device='cuda:0')
# tensor(2316, device='cuda:0') 3302
# tensor([0.3995], device='cuda:0')
# tensor(2318, device='cuda:0') 3305
# tensor([0.2723], device='cuda:0')
# tensor(2320, device='cuda:0') 3308
# tensor([0.3799], device='cuda:0')
# tensor(2321, device='cuda:0') 3311
# tensor([0.3740], device='cuda:0')
# tensor(2330, device='cuda:0') 3314
# tensor([0.3822], device='cuda:0')
# tensor(2331, device='cuda:0') 3317
# tensor([0.3575], device='cuda:0')
# tensor(2337, device='cuda:0') 3320
# tensor([0.3509], device='cuda:0')
# tensor(2341, device='cuda:0') 3323
# tensor([0.3691], device='cuda:0')
# tensor(2342, device='cuda:0') 3326
# tensor([0.3100], device='cuda:0')
# tensor(2346, device='cuda:0') 3329
# tensor([0.3357], device='cuda:0')
# tensor(2347, device='cuda:0') 3332
# tensor([0.4320], device='cuda:0')
# tensor(2353, device='cuda:0') 3335
# tensor([0.2003], device='cuda:0')
# tensor(2359, device='cuda:0') 3338
# tensor([0.7268], device='cuda:0')
# tensor(2365, device='cuda:0') 3341
# tensor([0.5000], device='cuda:0')
# tensor(2368, device='cuda:0') 3344
# tensor([0.4956], device='cuda:0')
# tensor(2383, device='cuda:0') 3347
# tensor([0.4021], device='cuda:0')
# tensor(2384, device='cuda:0') 3350
# tensor([0.5192], device='cuda:0')
# tensor(2389, device='cuda:0') 3353
# tensor([0.2774], device='cuda:0')
# tensor(2392, device='cuda:0') 3356
# tensor([0.2625], device='cuda:0')
# tensor(2411, device='cuda:0') 3359
# tensor([0.4319], device='cuda:0')
# tensor(2425, device='cuda:0') 3362
# tensor([0.4435], device='cuda:0')
# tensor(2427, device='cuda:0') 3365
# tensor([0.3159], device='cuda:0')
# tensor(2428, device='cuda:0') 3368
# tensor([0.5944], device='cuda:0')
# tensor(2431, device='cuda:0') 3371
# tensor([0.3868], device='cuda:0')
# tensor(2433, device='cuda:0') 3374
# tensor([0.4449], device='cuda:0')
# tensor(2435, device='cuda:0') 3377
# tensor([0.2030], device='cuda:0')
# tensor(2438, device='cuda:0') 3380
# tensor([0.2168], device='cuda:0')
# tensor(2445, device='cuda:0') 3383
# tensor([0.2753], device='cuda:0')
# tensor(2446, device='cuda:0') 3386
# tensor([0.2625], device='cuda:0')
# tensor(2448, device='cuda:0') 3389
# tensor([0.4165], device='cuda:0')
# tensor(2456, device='cuda:0') 3392
# tensor([0.3721], device='cuda:0')
# tensor(2459, device='cuda:0') 3395
# tensor([0.4857], device='cuda:0')
# tensor(2461, device='cuda:0') 3398
# tensor([0.3622], device='cuda:0')
# tensor(2467, device='cuda:0') 3401
# tensor([0.2588], device='cuda:0')
# tensor(2474, device='cuda:0') 3404
# tensor([0.3655], device='cuda:0')
# tensor(2479, device='cuda:0') 3407
# tensor([0.2830], device='cuda:0')
# tensor(2483, device='cuda:0') 3410
# tensor([0.3875], device='cuda:0')
# tensor(2489, device='cuda:0') 3413
# tensor([0.3621], device='cuda:0')
# tensor(2490, device='cuda:0') 3416
# tensor([0.3877], device='cuda:0')
# tensor(2496, device='cuda:0') 3419
# tensor([0.3364], device='cuda:0')
# tensor(2505, device='cuda:0') 3422
# tensor([0.3486], device='cuda:0')
# tensor(2508, device='cuda:0') 3425
# tensor([0.4274], device='cuda:0')
# tensor(2509, device='cuda:0') 3428
# tensor([0.3937], device='cuda:0')
# tensor(2514, device='cuda:0') 3431
# tensor([0.3593], device='cuda:0')
# tensor(2523, device='cuda:0') 3434
# tensor([0.2969], device='cuda:0')
# tensor(2533, device='cuda:0') 3437
# tensor([0.3540], device='cuda:0')
# tensor(2540, device='cuda:0') 3440
# tensor([0.5415], device='cuda:0')
# tensor(2543, device='cuda:0') 3443
# tensor([0.3532], device='cuda:0')
# tensor(2549, device='cuda:0') 3446
# tensor([0.2531], device='cuda:0')
# tensor(2552, device='cuda:0') 3449
# tensor([0.2803], device='cuda:0')
# tensor(2557, device='cuda:0') 3452
# tensor([0.3773], device='cuda:0')
# tensor(2561, device='cuda:0') 3455
# tensor([0.3412], device='cuda:0')
# tensor(2562, device='cuda:0') 3458
# tensor([0.4045], device='cuda:0')
# tensor(2566, device='cuda:0') 3461
# tensor([0.3561], device='cuda:0')
# tensor(2568, device='cuda:0') 3464
# tensor([0.4490], device='cuda:0')
# tensor(2578, device='cuda:0') 3467
# tensor([0.3009], device='cuda:0')
# tensor(2582, device='cuda:0') 3470
# tensor([0.2929], device='cuda:0')
# tensor(2586, device='cuda:0') 3473
# tensor([0.3877], device='cuda:0')
# tensor(2592, device='cuda:0') 3476
# tensor([0.2845], device='cuda:0')
# tensor(2598, device='cuda:0') 3479
# tensor([0.3430], device='cuda:0')
# tensor(2599, device='cuda:0') 3482
# tensor([0.3874], device='cuda:0')
# tensor(2603, device='cuda:0') 3485
# tensor([0.3590], device='cuda:0')
# tensor(2604, device='cuda:0') 3488
# tensor([0.3384], device='cuda:0')
# tensor(2614, device='cuda:0') 3491
# tensor([0.3517], device='cuda:0')
# tensor(2618, device='cuda:0') 3494
# tensor([0.5719], device='cuda:0')
# tensor(2631, device='cuda:0') 3497
# tensor([0.3451], device='cuda:0')
# tensor(2641, device='cuda:0') 3500
# tensor([0.2804], device='cuda:0')
# tensor(2642, device='cuda:0') 3503
# tensor([0.2545], device='cuda:0')
# tensor(2646, device='cuda:0') 3506
# tensor([0.3673], device='cuda:0')
# tensor(2647, device='cuda:0') 3509
# tensor([0.2705], device='cuda:0')
# tensor(2653, device='cuda:0') 3512
# tensor([0.2769], device='cuda:0')
# tensor(2658, device='cuda:0') 3515
# tensor([0.3961], device='cuda:0')
# tensor(2668, device='cuda:0') 3518
# tensor([0.3908], device='cuda:0')
# tensor(2669, device='cuda:0') 3521
# tensor([0.1877], device='cuda:0')
# tensor(2681, device='cuda:0') 3524
# tensor([0.3756], device='cuda:0')
# tensor(2685, device='cuda:0') 3527
# tensor([0.3420], device='cuda:0')
# tensor(2686, device='cuda:0') 3530
# tensor([0.0512], device='cuda:0')
# tensor(2689, device='cuda:0') 3533
# tensor([0.2046], device='cuda:0')
# tensor(2690, device='cuda:0') 3536
# tensor([0.5279], device='cuda:0')
# tensor(2699, device='cuda:0') 3539
# tensor([0.2538], device='cuda:0')
# tensor(2700, device='cuda:0') 3542
# tensor([0.1872], device='cuda:0')
# tensor(2702, device='cuda:0') 3545
# tensor([0.2510], device='cuda:0')
# tensor(2707, device='cuda:0') 3548
# tensor([0.3725], device='cuda:0')
